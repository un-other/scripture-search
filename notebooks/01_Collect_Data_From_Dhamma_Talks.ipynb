# %% [markdown]
# # Collect Data from Dhamma Talks (2025-03-02)
# In this notebook, we will collect data from the Dhamma Talks website.

# %%
# %load_ext autoreload
# %autoreload 2

import os

# Move execution back one directory.
os.chdir('..')

# %%
from scripture_search.data_collection.dhamma_talks import DhammaTalksCollector

collector = DhammaTalksCollector()

# %%
data = collector.get_data()
data.head()
# Out:
# 2025-04-13 10:15:31 - scripture_search.data_collection.data_collector - INFO - Data not found at /Users/anthonydachille/code/unother/scripture-search/data/dhamma_talks_suttas.csv or force_refresh is True, collecting data...
# 2025-04-13 10:15:31 - scripture_search.data_collection.data_collector - INFO - Getting sutta page links from index pages
#   0%|          | 0/5 [00:00<?, ?it/s]2025-04-13 10:15:31 - scripture_search.data_collection.data_collector - INFO - Processing sutta collection: AN
#  20%|██        | 1/5 [00:02<00:10,  2.74s/it]2025-04-13 10:15:34 - scripture_search.data_collection.data_collector - INFO - Processing sutta collection: DN
#  40%|████      | 2/5 [00:08<00:13,  4.54s/it]2025-04-13 10:15:40 - scripture_search.data_collection.data_collector - INFO - Processing sutta collection: KN
# 2025-04-13 10:15:40 - scripture_search.data_collection.data_collector - INFO - Processing sutta collection: MN
#  80%|████████  | 4/5 [00:51<00:15, 15.29s/it]2025-04-13 10:16:23 - scripture_search.data_collection.data_collector - INFO - Processing sutta collection: SN
# 100%|██████████| 5/5 [01:30<00:00, 18.17s/it]
# 2025-04-13 10:17:02 - scripture_search.data_collection.data_collector - INFO - Collected 240 suttas
# 2025-04-13 10:17:02 - scripture_search.data_collection.data_collector - INFO - Saving data to /Users/anthonydachille/code/unother/scripture-search/data/dhamma_talks_suttas.csv
#   collection                    title  \
# 0         AN           A Single Thing
# 1         AN          A Pool of Water
# 2         AN                     Soft
# 3         AN  Quick to Reverse Itself
# 4         AN                 Luminous
#
#                                        original_text  \
# 0  21. “I don’t envision a single thing that, whe...
# 1  45. “Suppose there were a pool of water—sullie...
# 2  “Just as, of all trees, the balsam is foremost...
# 3  “I don’t envision a single thing that is as qu...
# 4  “Luminous, monks, is the mind.1 And it is defi...
#
#                                           url_source  \
# 0  https://www.dhammatalks.org/suttas/AN/AN1_21.html
# 1  https://www.dhammatalks.org/suttas/AN/AN1_45.html
# 2  https://www.dhammatalks.org/suttas/AN/AN1_48.html
# 3  https://www.dhammatalks.org/suttas/AN/AN1_49.html
# 4  https://www.dhammatalks.org/suttas/AN/AN1_50.html
#
#                                           clean_text  religion   subgroup  \
# 0  21. "I don't envision a single thing that, whe...  Buddhism  Theravada
# 1  45. "Suppose there were a pool of water--sulli...  Buddhism  Theravada
# 2  "Just as, of all trees, the balsam is foremost...  Buddhism  Theravada
# 3  "I don't envision a single thing that is as qu...  Buddhism  Theravada
# 4  "Luminous, monks, is the mind.1 And it is defi...  Buddhism  Theravada
#
#          source  translation_source
# 0  Dhamma Talks  Thanissaro Bhikkhu
# 1  Dhamma Talks  Thanissaro Bhikkhu
# 2  Dhamma Talks  Thanissaro Bhikkhu
# 3  Dhamma Talks  Thanissaro Bhikkhu
# 4  Dhamma Talks  Thanissaro Bhikkhu
